# %% [markdown]
# # API 資料串接 - 以 Dcard API 實作範例
#
# * 了解 Dcard API 使用方式與回傳內容
# * 撰寫程式存取 API 且解析 JSON 格式資料

# %%
import requests
r = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')
response = r.text
response
# Out:
# '[{"id":234054522,"title":"洗衣機不是拿來洗貓的！","excerpt":"️洗衣機平常門是關的，----7/16更----，感謝大家熱情的留言都有看過 無法依依回覆，洗衣機是LG的洗脫烘的喔！，洗衣機平常門都會關起來 請大家放心，當時他跑進去還真的蠻怕他像倉鼠在裡面跑的，-","anonymousSchool":false,"anonymousDepartment":false,"pinned":false,"forumId":"7ee21581-1307-4ba9-b9dc-82028bdcca49","replyId":null,"createdAt":"2020-07-15T05:22:23.642Z","updatedAt":"2020-07-16T13:13:22.229Z","commentCount":35,"likeCount":1290,"withNickname":true,"tags":[],"topics":["洗衣機","貓","寵物","可愛","米克斯"],"meta":{"layout":"classic"},"forumName":"寵物","forumAlias":"pet","nsfw":false,"gender":"M","school":"3catbabe","department":"alvin_may","replyTitle":null,"mediaMeta":[{"id":"bf09ab67-fb89-424b-9d74-84fe6245394b","url":"https://i.imgur.com/dw7uPGal.jpg","normalizedUrl":"https://i.imgur.com/dw7uPGal.jpg","thumbnail":"https://i.imgur.com/dw7uPGal.jpg","type":"image/thumbnail","tags":["ANNOTATED"],"createdAt":"2020-07-15T05:22:23.642Z","updatedAt":"2020-07-16T13:13:22.229Z"},{"id":"bf09ab67-fb89-424b-9d74-84fe6245394b","url":"https://i.imgur.com/dw7uPGa.jpg","normalizedUrl":"https://imgur.com/dw7uPGa","thumbnail":"https://i.imgur.com/dw7uPGal.jpg","type":"image/imgur","tags":["ANNOTATED"],"createdAt":"2020-07-15T05:22:23.642Z","updatedAt":"2020-07-16T13:13:22.229Z"},{"id":"acb33689-0038-444f-a2f4-a3371100169a","url":"https://i.imgur.com/lVnwZz3.jpg","normalizedUrl":"https://imgur.com/lVnwZz3","thumbnail":"https://i.imgur.com/lVnwZz3l.jpg","type":"image/imgur","tags":["ANNOTATED"],"createdAt":"2020-07-15T05:22:23.642Z","updatedAt":"2020-07-16T13:13:22.229Z"},{"id":"5194a8b4-4cd9-472a-80a5-95e90c8c5259","url":"https://www.dcard.tw/v2/vivid/videos/320b52e9-7a26-41dc-b757-c79602e86c30?r=0.5625","normalizedUrl":"","thumbnail":"https://vivid.dcard.tw/Public/320b52e9-7a26-41dc-b757-c79602e86c30/thumbnail.jpg","type":"video/vivid","tags":["ANNOTATED_FAILED"],"createdAt":"2020-07-15T05:22:23.642Z","updatedAt":"2020-07-16T13:13:22.229Z"},{"id":"8299939c-2875-407b-9274-dd61b61a1391","url":"https://i.imgur.com/WjM5JbM.jpg","normalizedUrl":"https://imgur.com/WjM5JbM","thumbnail":"https://i.imgur.com/WjM5JbMl.jpg","type":"image/imgur","tags":["ANNOTATED"],"createdAt":"2020-07-15T05:26:42.407Z","updatedAt":"2020-07-16T13:13:22.229Z"},{"id":"abab513a-c0da-42e4-95be-363de9f79045","url":"https://i.imgur.com/WsxrZhc.jpg","normalizedUrl":"https://imgur.com/WsxrZhc","thumbnail":"https://i.imgur.com/WsxrZhcl.jpg","type":"image/imgur","tags":["ANNOTATED"],"createdAt":"2020-07-15T05:26:42.407Z","updatedAt":"2020-07-16T13:13:22.229Z"}],"reactions":[{"id":"286f599c-f86a-4932-82f0-f5a06f1eca03","count":1257},{"id":"e8e6bc5d-41b0-4129-b134-97507523d7ff","count":33}],"hidden":false,"customStyle":null,"isSuspiciousAccount":false,"layout":"classic","withImages":true,"withVideos":true,"media":[{"url":"https://i.imgur.com/dw7uPGa.jpg"},{"url":"https://i.imgur.com/lVnwZz3.jpg"},{"url":"https://vivid.dcard.tw/Public/320b52e9-7a26-41dc-b757-c79602e86c30/thumbnail.jpg"},{"url":"https://i.imgur.com/WjM5JbM.jpg"},{"url":"https://i.imgur.com/WsxrZhc.jpg"}],"reportReasonText":"","postAvatar":""},{"id":234054570,"title":"領養了一隻小貓❤️🐱","excerpt":"他的送養文是送養人，看到他前主人將他關在廁所飼養，環境髒亂不堪 甚至腹部的毛因為壓力都掉光了，我那天 一看到文章當下 跟家裡討論好，馬上就跟送養人聯絡，當下就從彰化直接衝去台中了，看到他的第一眼 我就","anonymousSchool":false,"anonymousDepartment":true,"pinned":false,"forumId":"7ee21581-1307-4ba9-b9dc-82028bdcca49","replyId":null,"createdAt":"2020-07-15T05:30:06.804Z","updatedAt":"2020-07-15T05:30:06.804Z","commentCount":26,"likeCount":886,"withNickname":false,"tags":[],"topics":["貓","領養","領養代替購買","領養不棄養"],"meta":{"layout":"classic"},"forumName":"寵物","forumAlias":"pet","nsfw":false,"gender":"F","school":"國立臺中科技大學","replyTitle":null,"mediaMeta":[{"id":"83ee4235-8581-4334-8022-103322df87bf","url":"https://megapx-assets.dcard.tw/images/be90d937-dffc-436f-ba3e-183942fc2e87/160.jpeg","normalizedUrl":"https://megapx-assets.dcard.tw/images/be90d937-dffc-436f-ba3e-183942fc2e87/160.jpeg","thumbnail":"https://megapx-assets.dcard.tw/images/be90d937-dffc-436f-ba3e-183942fc2e87/160.jpeg"," ...

# %%
import json
data = json.loads(response)
for d in data:
    print(d['title'])
# Out:
# 1 洗衣機不是拿來洗貓的！
# 2 領養了一隻小貓❤️🐱
# 3 一個月貓咪到底可以胖多少呢？
# 4 超級髒的貓
# 5 黑貓可愛爆
# 6 惡魔柴犬COCO
# 7 要來吸鼠嗎🐹
# 8 幫黃金鼠結紮小分享🐹(字很多
# 9 擁有單邊眉毛+圍圍巾的貓
# 10 要來我家嗎？我家貓有美腿
# 11 養狗十誡，你做到幾個?
# 12 貓咪打呼嚕背後代表的幾種涵義
# 13 浪浪小花的寶寶們！
# 14 請問大家在養狗前考慮了多久💭
# 15 狗狗走失 雪納瑞 求大家幫忙
# 16 有人的貓會這樣嗎
# 17 米克斯也是很可愛的～～
# 18 是夢到了什麼好吃的？
# 19 上班前的小確幸
# 20 世界上最可愛的瑪爾
# 21 啊柴進化篇
# 22 我家小蛙超可愛
# 23 我是一隻愛笑的貓
# 24 曬狗！在我心中最可愛的胡麻柴小寶貝💗
# 25 轉：原來捕狗隊這樣處置懷孕母狗？
# 26 #貓 模範天使浪浪
# 27 我家貓貓好可愛
# 28 寵物監視器
# 29 ［問卷］貓狗寵物飼主調查｜有抽獎+小故事
# 30 各種睡覺的貓

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

# %%
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
print("回傳",len(data),"筆資料")
for d in data:
    print(d.keys())
# Out:
# 回傳 30 筆資料
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'nsfw', 'gender', 'school', 'department', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'nsfw', 'gender', 'school', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'nsfw', 'gender', 'school', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'nsfw', 'gender', 'school', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'nsfw', 'gender', 'school', 'department', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'nsfw', 'gender', 'school', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'nsfw', 'gender', 'school', 'department', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'nsfw', 'gender', 'school', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'nsfw', 'gender', 'school', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'nsfw', 'gender', 'school', 'department', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'nsfw', 'gender', 'school', 'department', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'nsfw', 'gender', 'school', 'department', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'nsfw', 'gender', 'school', 'department', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'nsfw', 'gender', 'school', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'nsfw', 'gender', 'school', 'department', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'nsfw', 'gender', 'school', 'department', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'nsfw', 'gender', 'school', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'nsfw', 'gender', 'school', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'nsfw', 'gender', 'school', 'department', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'nsfw', 'gender', 'school', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'nsfw', 'gender', 'school', 'department', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'nsfw', 'gender', 'school', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'nsfw', 'gender', 'school', 'department', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'nsfw', 'gender', 'school', 'department', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'nsfw', 'gender', 'school', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'nsfw', 'gender', 'school', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'categories', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'nsfw', 'gender', 'school', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'nsfw', 'gender', 'school', 'department', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'nsfw', 'gender', 'school', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'nsfw', 'gender', 'school', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])

# %%
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
text=[]
for d in data:
    print(d['title'],"/",d['createdAt'],"/",d['commentCount'],"/",d['likeCount'])
# Out:
# 洗衣機不是拿來洗貓的！ / 2020-07-15T05:22:23.642Z / 35 / 1290
# 領養了一隻小貓❤️🐱 / 2020-07-15T05:30:06.804Z / 26 / 886
# 一個月貓咪到底可以胖多少呢？ / 2020-07-15T09:43:52.870Z / 13 / 244
# 超級髒的貓 / 2020-07-15T06:57:35.821Z / 16 / 140
# 黑貓可愛爆 / 2020-07-15T04:57:21.346Z / 4 / 78
# 惡魔柴犬COCO / 2020-07-15T08:15:55.921Z / 5 / 67
# 要來吸鼠嗎🐹 / 2020-07-15T16:14:26.861Z / 3 / 30
# 幫黃金鼠結紮小分享🐹(字很多 / 2020-07-15T11:25:56.439Z / 1 / 26
# 擁有單邊眉毛+圍圍巾的貓 / 2020-07-15T16:23:07.436Z / 10 / 25
# 要來我家嗎？我家貓有美腿 / 2020-07-16T03:30:01.200Z / 2 / 24
# 養狗十誡，你做到幾個? / 2020-07-15T16:29:33.218Z / 2 / 24
# 貓咪打呼嚕背後代表的幾種涵義 / 2020-07-16T04:16:21.692Z / 0 / 18
# 浪浪小花的寶寶們！ / 2020-07-15T17:26:25.962Z / 4 / 16
# 請問大家在養狗前考慮了多久💭 / 2020-07-15T13:59:39.112Z / 15 / 13
# 狗狗走失 雪納瑞 求大家幫忙 / 2020-07-15T06:56:15.725Z / 0 / 13
# 有人的貓會這樣嗎 / 2020-07-16T11:33:04.292Z / 2 / 12
# 米克斯也是很可愛的～～ / 2020-07-16T01:23:26.354Z / 4 / 12
# 是夢到了什麼好吃的？ / 2020-07-15T02:08:57.616Z / 4 / 12
# 上班前的小確幸 / 2020-07-16T06:01:51.996Z / 4 / 11
# 世界上最可愛的瑪爾 / 2020-07-15T10:14:24.491Z / 2 / 9
# 啊柴進化篇 / 2020-07-15T09:22:12.376Z / 0 / 7
# 我家小蛙超可愛 / 2020-07-15T15:08:16.981Z / 5 / 6
# 我是一隻愛笑的貓 / 2020-07-16T10:08:25.791Z / 0 / 4
# 曬狗！在我心中最可愛的胡麻柴小寶貝💗 / 2020-07-15T14:03:07.856Z / 1 / 4
# 轉：原來捕狗隊這樣處置懷孕母狗？ / 2020-07-15T12:44:14.691Z / 3 / 4
# #貓 模範天使浪浪 / 2020-07-16T12:40:53.557Z / 0 / 3
# 我家貓貓好可愛 / 2020-07-16T12:38:56.772Z / 1 / 3
# 寵物監視器 / 2020-07-15T13:04:26.457Z / 7 / 3
# ［問卷］貓狗寵物飼主調查｜有抽獎+小故事 / 2020-07-15T13:00:12.818Z / 7 / 3
# 各種睡覺的貓 / 2020-07-16T12:45:31.687Z / 0 / 2

# %%
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」
commentsum=0
likesum=0
for d in data:
    commentsum+=d['commentCount']
    likesum+=d['likeCount']
print("平均留言人數:",commentsum/30,"\n")
print("平均按讚人數:",likesum/30,"\n")
# Out:
# 平均留言人數: 5.866666666666666
#
# 平均按讚人數: 99.63333333333334
